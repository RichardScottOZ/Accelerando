# %% [markdown]
# # Accelerando: Lobsters
#
# A text-based adventure/simulation game based on Charles Stross's science fiction novel *Accelerando*, focusing on the themes from the "Lobsters" chapter.
#
# Play as a meme-broker navigating the technological singularity in the early 21st century. Make decisions about AI rights, patent liberation, and digital consciousness while managing your reputation in an agalmic (post-scarcity) economy.
#
# ## How to Play
#
# The game is an interactive terminal application. To play:
#
# 1. Open a terminal: **File → New → Terminal** (in JupyterLab) or click the **Terminal** icon in the Launcher
# 2. In the terminal, run:
#    ```
#    python accelerando_game.py
#    ```
# 3. Follow the prompts and make your choices!
#
# ## Resources
#
# - **Reputation** — your primary currency in the agalmic economy
# - **Ideas** — generate and share to gain reputation
# - **Bandwidth** — needed for digital entity interactions
# - **Influence** — used to affect policy and legal decisions
#
# ## Win Conditions
#
# - Reach the Singularity with high reputation (50+)
# - Successfully help 10+ digital entities with 75+ reputation
# - Transform society toward post-scarcity ideals
#
# ---
# *Based on "Accelerando" by Charles Stross, available under Creative Commons at https://www.antipope.org/charlie/blog-static/fiction/accelerando/accelerando.html*

# %%
# Run the cell below to open a terminal and start the game.
# In JupyterLab you can also use File → New → Terminal, then run:
#   python accelerando_game.py

import subprocess, sys
print("Python version:", sys.version)
print()
print("To play the game, open a terminal (File → New → Terminal) and run:")
print("  python accelerando_game.py")

# %%
# Verify game file is present
import os
if os.path.exists("accelerando_game.py"):
    print("✓ accelerando_game.py found — open a terminal and run: python accelerando_game.py")
else:
    print("✗ accelerando_game.py not found in current directory")
